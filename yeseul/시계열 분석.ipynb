# %%
import pandas as pd

# %%
df=pd.read_csv('현대_시장구분별_내수차량_모델별월간판매량.csv')

# %%
df
# Out:
#           국가            차량 모델    연도    월   판매량
# 0     아시아-인도     Santro (AH2)  2023   1월     0
# 1     아시아-인도   Xcent (BA 4DR)  2023   1월     0
# 2     아시아-인도   Aura (AI3 4DR)  2023   1월  4634
# 3     아시아-인도   NIOS (AI3 5DR)  2023   1월  8760
# 4     아시아-인도    i20 (BI3 5DR)  2023   1월  8185
# ...      ...              ...   ...  ...   ...
# 2755  아시아-기타     County (CSv)  2025  12월     0
# 2756  아시아-기타     Solati (Euv)  2025  12월     0
# 2757  아시아-기타  Santa Fe (MX5v)  2025  12월     0
# 2758  아시아-기타      IONIQ5 (NE)  2025  12월     0
# 2759  아시아-기타      IONIQ6 (CE)  2025  12월     0
#
# [2760 rows x 5 columns]

# %%
# 월에서 '월' 글자 제거 → 정수형으로 변환
df["월"] = df["월"].str.replace("월", "").astype(int)

# %%
df
# Out:
#           국가            차량 모델    연도   월   판매량
# 0     아시아-인도     Santro (AH2)  2023   1     0
# 1     아시아-인도   Xcent (BA 4DR)  2023   1     0
# 2     아시아-인도   Aura (AI3 4DR)  2023   1  4634
# 3     아시아-인도   NIOS (AI3 5DR)  2023   1  8760
# 4     아시아-인도    i20 (BI3 5DR)  2023   1  8185
# ...      ...              ...   ...  ..   ...
# 2755  아시아-기타     County (CSv)  2025  12     0
# 2756  아시아-기타     Solati (Euv)  2025  12     0
# 2757  아시아-기타  Santa Fe (MX5v)  2025  12     0
# 2758  아시아-기타      IONIQ5 (NE)  2025  12     0
# 2759  아시아-기타      IONIQ6 (CE)  2025  12     0
#
# [2760 rows x 5 columns]

# %%
df["날짜"] = pd.to_datetime(df["연도"].astype(str) + "-" + df["월"].astype(str), format="%Y-%m")

# %%
df
# Out:
#           국가            차량 모델    연도   월   판매량         날짜
# 0     아시아-인도     Santro (AH2)  2023   1     0 2023-01-01
# 1     아시아-인도   Xcent (BA 4DR)  2023   1     0 2023-01-01
# 2     아시아-인도   Aura (AI3 4DR)  2023   1  4634 2023-01-01
# 3     아시아-인도   NIOS (AI3 5DR)  2023   1  8760 2023-01-01
# 4     아시아-인도    i20 (BI3 5DR)  2023   1  8185 2023-01-01
# ...      ...              ...   ...  ..   ...        ...
# 2755  아시아-기타     County (CSv)  2025  12     0 2025-12-01
# 2756  아시아-기타     Solati (Euv)  2025  12     0 2025-12-01
# 2757  아시아-기타  Santa Fe (MX5v)  2025  12     0 2025-12-01
# 2758  아시아-기타      IONIQ5 (NE)  2025  12     0 2025-12-01
# 2759  아시아-기타      IONIQ6 (CE)  2025  12     0 2025-12-01
#
# [2760 rows x 6 columns]

# %%
df = df[df["날짜"] < "2025-02-01"]

# %%
df['날짜'].unique()
# Out:
# <DatetimeArray>
# ['2023-01-01 00:00:00', '2024-01-01 00:00:00', '2025-01-01 00:00:00',
#  '2023-02-01 00:00:00', '2024-02-01 00:00:00', '2023-03-01 00:00:00',
#  '2024-03-01 00:00:00', '2023-04-01 00:00:00', '2024-04-01 00:00:00',
#  '2023-05-01 00:00:00', '2024-05-01 00:00:00', '2023-06-01 00:00:00',
#  '2024-06-01 00:00:00', '2023-07-01 00:00:00', '2024-07-01 00:00:00',
#  '2023-08-01 00:00:00', '2024-08-01 00:00:00', '2023-09-01 00:00:00',
#  '2024-09-01 00:00:00', '2023-10-01 00:00:00', '2024-10-01 00:00:00',
#  '2023-11-01 00:00:00', '2024-11-01 00:00:00', '2023-12-01 00:00:00',
#  '2024-12-01 00:00:00']
# Length: 25, dtype: datetime64[ns]

# %%
df['차량 모델'].unique()
# Out:
# array([' Santro (AH2)', ' Xcent (BA 4DR)', ' Aura (AI3 4DR)',
#        ' NIOS (AI3 5DR)', ' i20 (BI3 5DR)', ' Verna (Hci)',
#        ' Verna (BN7i)', 'Exter (AI3 SUV)', ' Venue (QXi)',
#        ' Creta (SU2i)', ' Creta (SU2i LWB)', ' Kona EV (OSi EV)',
#        'IONIQ5 (NEi)', ' Tucson (TLi)', ' Tucson (NX4i)', 'i10 (AC3)',
#        'i20 (BC3)', 'Bayon (BC3 CUV)', 'i20 N (BC3 N)', ' Reina (CB)',
#        ' Verna (YC)', ' Celesta (ID)', ' Elantra (CN7c)',
#        ' La festa (SQ)', ' La festa EV (SQ EV)', ' Mistra (DU2)',
#        ' Mistra EV (DU2 EV)', ' Sonata (DN8c)', ' Custo (KU)',
#        ' ix25 (SU2)', ' Tucson (NX4c)', ' Tucson HEV (NX4c HEV)',
#        ' ix35 (NU)', ' ix35 (NU2)', ' Santa Fe (TMc)', 'Elantra (CN7a)',
#        'Sonata (DN8a)', 'Tucson (NX4a)', 'Tucson OB (NX4a OB)',
#        'Santa-Fe (TMa)', 'Santa-Fe HEV (TMa HEV)', 'GV70 (JKa)',
#        'GV70 EV (Jka EV)', 'Solaris (HCr)', 'Creta (SU2r)', 'Kia Rio(FB)',
#        'HB20 (BR2)', 'Creta (GSb)', 'Creta (SU2b)', 'Stargazer (KS)',
#        'IONIQ5 (NE)', 'Santa-Fe (TMid)', 'Creta (SU2id)', 'HTBC', 'CV',
#        'i10(AI3v 4DR)', 'i10(AI3v 5DR)', 'Accent (HCv)', 'Elantra (ADv)',
#        'Elantra (CN7v)', 'Kona (OSv)', 'Creta (SU2v)', 'Tucson (TLv)',
#        'Tucson (NX4v)', 'Santa Fe (TMv)', 'Santa Fe HEV (TMv HEV)',
#        'Palisade (LX2v)', 'Kusto (KUv)', 'IONIQ5 (NEv)', 'Porter (HRv)',
#        'Mighty (LTv)', 'Mighty (VTv)', 'Mighty (QTv)', 'Mighty (QTc)',
#        'Truck', ' Xcent (AI3 4DR)', ' Grand i10 (AI3 5DR)',
#        ' IONIQ5 (NEi)', ' Mufasa (NU2)', ' Santa Fe (MX5c)',
#        'Santa-Fe (MX5a)', 'Santa-Fe (MX5a HEV)', 'Ioniq5 (NEa)',
#        'Kona EV (SX2id EV) ', 'IONIQ5 (NEid N)', 'Santa-Fe (MX5id)',
#        'Santa-Fe (MX5id HEV)', 'NX4m', 'HCm', 'Accent (BN7v)',
#        'Venue (QXv)', 'Santa Fe (MX5v)', 'IONIQ6 (CE)',
#        ' Creta (SU2i EV)', 'IONIQ5 (NEid)', 'County (CSv)',
#        'Solati (Euv)'], dtype=object)

# %%
df['국가'].unique()
# Out:
# array(['아시아-인도', '아시아-중국', '북미-미국', '동유럽', '중남미', '아시아-기타', '북미-멕시코'],
#       dtype=object)

# %%
from prophet import Prophet

# %%
df
# Out:
#           국가            차량 모델    연도   월   판매량         날짜
# 0     아시아-인도     Santro (AH2)  2023   1     0 2023-01-01
# 1     아시아-인도   Xcent (BA 4DR)  2023   1     0 2023-01-01
# 2     아시아-인도   Aura (AI3 4DR)  2023   1  4634 2023-01-01
# 3     아시아-인도   NIOS (AI3 5DR)  2023   1  8760 2023-01-01
# 4     아시아-인도    i20 (BI3 5DR)  2023   1  8185 2023-01-01
# ...      ...              ...   ...  ..   ...        ...
# 2679  아시아-기타     Mighty (QTv)  2024  12     0 2024-12-01
# 2680  아시아-기타     Mighty (QTc)  2024  12     0 2024-12-01
# 2681  아시아-기타  Santa Fe (MX5v)  2024  12   418 2024-12-01
# 2682  아시아-기타      IONIQ5 (NE)  2024  12     0 2024-12-01
# 2683  아시아-기타      IONIQ6 (CE)  2024  12    12 2024-12-01
#
# [1924 rows x 6 columns]

# %%
df_filtered = df[
    (df["국가"] == "북미-미국") &
    (df["차량 모델"] == "Santa-Fe (MX5a)")
]

# %%
df_filtered
# Out:
#          국가            차량 모델    연도   월    판매량         날짜
# 111   북미-미국  Santa-Fe (MX5a)  2024   1   1935 2024-01-01
# 190   북미-미국  Santa-Fe (MX5a)  2025   1   6052 2025-01-01
# 341   북미-미국  Santa-Fe (MX5a)  2024   2   8882 2024-02-01
# 571   북미-미국  Santa-Fe (MX5a)  2024   3  11326 2024-03-01
# 801   북미-미국  Santa-Fe (MX5a)  2024   4  10577 2024-04-01
# 1031  북미-미국  Santa-Fe (MX5a)  2024   5  10474 2024-05-01
# 1261  북미-미국  Santa-Fe (MX5a)  2024   6   8263 2024-06-01
# 1491  북미-미국  Santa-Fe (MX5a)  2024   7   6780 2024-07-01
# 1721  북미-미국  Santa-Fe (MX5a)  2024   8   9518 2024-08-01
# 1951  북미-미국  Santa-Fe (MX5a)  2024   9   7769 2024-09-01
# 2181  북미-미국  Santa-Fe (MX5a)  2024  10  10053 2024-10-01
# 2411  북미-미국  Santa-Fe (MX5a)  2024  11   8141 2024-11-01
# 2641  북미-미국  Santa-Fe (MX5a)  2024  12   7784 2024-12-01

# %%
from prophet import Prophet
import pandas as pd

df_filtered.loc[:, "y"] = df_filtered["판매량"]
df_filtered.loc[:, "ds"] =df_filtered["날짜"]
df_model = df_filtered.dropna(subset=["y"])
if len(df_model) < 2:
    print("예측할 데이터가 부족합니다.")
else:
    model = Prophet()
    model.fit(df_model[["ds", "y"]])
    
    future = model.make_future_dataframe(periods=12, freq="ME")
    forecast = model.predict(future)
    
    print(forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(24))
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_40126/2341992513.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:, "y"] = df_filtered["판매량"]
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_40126/2341992513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:, "ds"] =df_filtered["날짜"]
# 15:22:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:22:52 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower    yhat_upper
# 1  2024-02-01  8254.899309  5464.171383  10934.002756
# 2  2024-03-01  8258.227014  5228.916320  11301.357107
# 3  2024-04-01  8261.784217  5297.092862  11259.093128
# 4  2024-05-01  8265.226670  5274.593403  11241.772266
# 5  2024-06-01  8268.783873  5482.198726  11009.846880
# 6  2024-07-01  8272.226327  5366.631008  11327.582269
# 7  2024-08-01  8275.783529  5097.159330  11130.645139
# 8  2024-09-01  8279.340732  5301.915396  11321.030166
# 9  2024-10-01  8282.783186  5284.539978  11349.486214
# 10 2024-11-01  8286.340388  5115.353497  11114.271085
# 11 2024-12-01  8289.782843  5256.715294  11191.852720
# 12 2025-01-01  8293.340045  5517.725308  11311.324428
# 13 2025-01-31  8296.782499  5165.792097  11303.998053
# 14 2025-02-28  8299.995456  5320.242527  11204.258037
# 15 2025-03-31  8303.552659  5247.813200  11365.024695
# 16 2025-04-30  8306.995113  5252.907021  11456.652556
# 17 2025-05-31  8310.552316  5424.709271  11421.568020
# 18 2025-06-30  8313.994770  5269.365230  11292.347076
# 19 2025-07-31  8317.551973  5476.065131  11411.086201
# 20 2025-08-31  8321.109175  5400.625656  11234.105982
# 21 2025-09-30  8324.551629  5237.845083  10993.075322
# 22 2025-10-31  8328.108832  5591.598051  11514.724577
# 23 2025-11-30  8331.551286  5432.223417  11275.986556
# 24 2025-12-31  8335.108489  5463.585578  11389.618785

# %%
df_eval = pd.merge(df_model[["ds", "y"]], forecast[["ds", "yhat"]], on="ds")

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd

# 예측 결과와 실제 데이터 병합
df_eval = pd.merge(df_model[["ds", "y"]], forecast[["ds", "yhat"]], on="ds")

# 성능 지표 계산
mae = mean_absolute_error(df_eval["y"], df_eval["yhat"])
mse = mean_squared_error(df_eval["y"], df_eval["yhat"])
rmse = np.sqrt(mse)
mape = (np.abs((df_eval["y"] - df_eval["yhat"]) / df_eval["y"])).mean() * 100

# 결과 출력
print(f"MAE  (평균 절대 오차): {mae:.2f}")
print(f"RMSE (평균 제곱근 오차): {rmse:.2f}")
print(f"MAPE (평균 절대 비율 오차): {mape:.2f}%")
# Out:
# MAE  (평균 절대 오차): 1726.80
# RMSE (평균 제곱근 오차): 2359.99
# MAPE (평균 절대 비율 오차): 39.09%

# %%
import matplotlib.pyplot as plt

# 날짜 정렬
df_eval["ds"] = pd.to_datetime(df_eval["ds"])
df_eval = df_eval.sort_values("ds")

plt.figure(figsize=(12, 6))
plt.plot(df_eval["ds"], df_eval["y"], label="실제값", marker='o')
plt.plot(df_eval["ds"], df_eval["yhat"], label="예측값", linestyle='--', marker='x')

plt.title("Prophet 예측 vs 실제 판매량")
plt.xlabel("날짜")
plt.ylabel("판매량")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)  # 날짜가 겹치지 않게 회전
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv('현대_시장구분별_수출실적.csv')

# %%
df.head()
# Out:
#        국가             대륙     1월     2월     3월     4월     5월     6월     7월  \
# 0   북미-미국  North America  33157  44040  44161  43894  51132  47682  46768
# 1  북미-캐나다  North America   9824  11958  11464  10792  10478  11495   8383
# 2  북미-멕시코  North America      8     82     57     45     69     31    202
# 3     서유럽         Europe   8949  14775  12550  11058  12274  13248   8080
# 4     서유럽         Europe   2127   1526   2525   3539   2940   2913   3767
#
#       8월     9월    10월    11월    12월    연도
# 0  46840  49241  57589  58435  58183  2023
# 1   6155   6143   9776  10729  11805  2023
# 2    216     75    130    200    112  2023
# 3   5970   6476   6753   7476   6762  2023
# 4   3675   3059   3625   2046   2875  2023

# %%
df = df.groupby(["국가", "연도"], as_index=False).sum(numeric_only=True)

# %%
df
# Out:
#          국가    연도     1월     2월     3월     4월     5월     6월     7월     8월  \
# 0        기타  2025     46      0      0      0      0      0      0      0
# 1       동유럽  2023   2535   3074   2598   3904   3768   3637   3578   3368
# 2       동유럽  2024   2373   3515   3637   3826   2186   2648   2140   2585
# 3       동유럽  2025   3025      0      0      0      0      0      0      0
# 4    북미-멕시코  2023      8     82     57     45     69     31    202    216
# 5    북미-멕시코  2024     60     51    287    373    194    150    143    146
# 6    북미-멕시코  2025     29      0      0      0      0      0      0      0
# 7     북미-미국  2023  33157  44040  44161  43894  51132  47682  46768  46840
# 8     북미-미국  2024  55421  43704  57669  63939  62068  55809  44859  52389
# 9     북미-미국  2025  41454      0      0      0      0      0      0      0
# 10   북미-캐나다  2023   9824  11958  11464  10792  10478  11495   8383   6155
# 11   북미-캐나다  2024  11189   9437  11914  10738  10512  12175  10867   8529
# 12   북미-캐나다  2025  10472      0      0      0      0      0      0      0
# 13      서유럽  2023  11076  16301  15075  14597  15214  16161  11847   9645
# 14      서유럽  2024   9697   9977  10436  12855   9898   9768   8614   7923
# 15      서유럽  2025  12315      0      0      0      0      0      0      0
# 16   아시아-기타  2023  11288   7295   8997  10570  10678  10496  10563   9940
# 17   아시아-기타  2024   6891   6057   7161   8351   7760   9011   7822   8918
# 18   아시아-기타  2025   6294      0      0      0      0      0      0      0
# 19      중남미  2023   3896   5092   4954   5758   4294   5538   4700   4796
# 20      중남미  2024   4772   4206   4805   4592   3392   4433   3766   3946
# 21      중남미  2025   4157      0      0      0      0      0      0      0
# 22  중동·아프리카  2023  10427  10128  12760  11043   9118   8908   9410   8890
# 23  중동·아프리카  2024   9074   6530   8131   9320   9390   9522  10005   6314
# 24  중동·아프리카  2025   7909      0      0      0      0      0      0      0
#
#        9월    10월    11월    12월
# 0       0      0      0      0
# 1    2604   3321   3165   2721
# 2    4095   4044   3273   2953
# 3       0      0      0      0
# 4      75    130    200    112
# 5     189    153    121     72
# 6       0      0      0      0
# 7   49241  57589  58435  58183
# 8   45941  52255  45782  57802
# 9       0      0      0      0
# 10   6143   9776  10729  11805
# 11  10163  12632   9098  10807
# 12      0      0      0      0
# 13   9535  10378   9522   9637
# 14   7781  10543  11755  12842
# 15      0      0      0      0
# 16   4984  10793   7556   7712
# 17  10004   7142   6838   7324
# 18      0      0      0      0
# 19   4068   5022   3691   4547
# 20   5439   4341   3448   5599
# 21      0      0      0      0
# 22   5963   8258   6651   8346
# 23   7645   9330   8768   8388
# 24      0      0      0      0

# %%
df.to_csv('현대_시장구분별_수출실적.csv', index=False)

# %%
df['국가'].unique()
# Out:
# array(['기타', '동유럽', '북미-멕시코', '북미-미국', '북미-캐나다', '서유럽', '아시아-기타', '중남미',
#        '중동·아프리카'], dtype=object)

# %%
# 2. melt로 월 컬럼 녹이기
df_melted = df.melt(
    id_vars=["국가", "연도"],
    value_vars=["1월", "2월", "3월", "4월", "5월", "6월", "7월", "8월", "9월", "10월", "11월", "12월"],
    var_name="월",
    value_name="y"
)

# 3. 날짜 컬럼 만들기 (ds)
df_melted["월"] = df_melted["월"].str.replace("월", "").astype(int)
df_melted["ds"] = pd.to_datetime(df_melted["연도"].astype(str) + "-" + df_melted["월"].astype(str), format="%Y-%m")



# 4. 수치 변환 및 정리
df_melted["y"] = pd.to_numeric(df_melted["y"], errors="coerce")
df_melted = df_melted.dropna(subset=["y"]).sort_values(["국가", "ds"]).reset_index(drop=True)

cutoff_date = pd.to_datetime("2025-01-31")
df_melted = df_melted[df_melted["ds"] <= cutoff_date].copy()

# %%
df_melted
# Out:
#           국가    연도   월     y         ds
# 0         기타  2025   1    46 2025-01-01
# 12       동유럽  2023   1  2535 2023-01-01
# 13       동유럽  2023   2  3074 2023-02-01
# 14       동유럽  2023   3  2598 2023-03-01
# 15       동유럽  2023   4  3904 2023-04-01
# ..       ...   ...  ..   ...        ...
# 284  중동·아프리카  2024   9  7645 2024-09-01
# 285  중동·아프리카  2024  10  9330 2024-10-01
# 286  중동·아프리카  2024  11  8768 2024-11-01
# 287  중동·아프리카  2024  12  8388 2024-12-01
# 288  중동·아프리카  2025   1  7909 2025-01-01
#
# [201 rows x 5 columns]

# %%
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

#한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 결과 저장 리스트
results = []

# 국가별 루프
for country in df_melted["국가"].unique():
    df_country = df_melted[df_melted["국가"] == country][["ds", "y"]].copy()

    if len(df_country) < 12:
        print(f"[{country}] 데이터 부족으로 스킵")
        continue

    model = Prophet()
    model.fit(df_country)

    future = model.make_future_dataframe(periods=24, freq="ME")
    forecast = model.predict(future)

    # 병합 후 평가
    df_eval = pd.merge(df_country, forecast[["ds", "yhat"]], on="ds", how="inner")
    df_eval = df_eval[df_eval["y"] != 0]  # MAPE용 0제거

    if len(df_eval) == 0:
        print(f"[{country}] 평가 불가 (y가 모두 0)")
        continue

    mae = mean_absolute_error(df_eval["y"], df_eval["yhat"])
    rmse = np.sqrt(mean_squared_error(df_eval["y"], df_eval["yhat"]))
    mape = (np.abs((df_eval["y"] - df_eval["yhat"]) / df_eval["y"])).mean() * 100

    # 저장
    results.append({
        "국가": country,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "MAPE": round(mape, 2)
    })

    # 시각화
    plt.figure(figsize=(10, 5))
    plt.plot(df_country["ds"], df_country["y"], label="실제값", marker='o')
    plt.plot(forecast["ds"], forecast["yhat"], label="예측값", linestyle="--")
    plt.fill_between(forecast["ds"], forecast["yhat_lower"], forecast["yhat_upper"], alpha=0.2, label="신뢰구간")
    plt.title(f"[{country}] 수출 실적 예측")
    plt.xlabel("날짜")
    plt.ylabel("수출량")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.savefig(f"{country}_수출실적.png")
    plt.show()
# Out:
# 15:58:07 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:08 - cmdstanpy - INFO - Chain [1] done processing
# [기타] 데이터 부족으로 스킵
# 15:58:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:08 - cmdstanpy - INFO - Chain [1] done processing
# 15:58:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:08 - cmdstanpy - INFO - Chain [1] done processing
# 15:58:08 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] done processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] done processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] done processing
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_41169/1552285197.py:56: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_41169/1552285197.py:58: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   plt.savefig(f"{country}_수출실적.png")
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   fig.canvas.print_figure(bytes_io, **kw)
# 15:58:09 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:09 - cmdstanpy - INFO - Chain [1] done processing
# 15:58:10 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:15 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_seu = df_melted[df_melted["국가"] == "서유럽"].copy()
df_seu
# Out:
#       국가    연도   월      y         ds
# 156  서유럽  2023   1  11076 2023-01-01
# 157  서유럽  2023   2  16301 2023-02-01
# 158  서유럽  2023   3  15075 2023-03-01
# 159  서유럽  2023   4  14597 2023-04-01
# 160  서유럽  2023   5  15214 2023-05-01
# 161  서유럽  2023   6  16161 2023-06-01
# 162  서유럽  2023   7  11847 2023-07-01
# 163  서유럽  2023   8   9645 2023-08-01
# 164  서유럽  2023   9   9535 2023-09-01
# 165  서유럽  2023  10  10378 2023-10-01
# 166  서유럽  2023  11   9522 2023-11-01
# 167  서유럽  2023  12   9637 2023-12-01
# 168  서유럽  2024   1   9697 2024-01-01
# 169  서유럽  2024   2   9977 2024-02-01
# 170  서유럽  2024   3  10436 2024-03-01
# 171  서유럽  2024   4  12855 2024-04-01
# 172  서유럽  2024   5   9898 2024-05-01
# 173  서유럽  2024   6   9768 2024-06-01
# 174  서유럽  2024   7   8614 2024-07-01
# 175  서유럽  2024   8   7923 2024-08-01
# 176  서유럽  2024   9   7781 2024-09-01
# 177  서유럽  2024  10  10543 2024-10-01
# 178  서유럽  2024  11  11755 2024-11-01
# 179  서유럽  2024  12  12842 2024-12-01
# 180  서유럽  2025   1  12315 2025-01-01

# %%
df_results = pd.DataFrame(results)
display(df_results.sort_values("MAPE"))  # MAPE 기준 정렬
# Out:
#         국가      MAE     RMSE   MAPE
# 7  중동·아프리카     0.01     0.01   0.00
# 3   북미-캐나다   114.18   161.02   1.09
# 5   아시아-기타   272.70   349.93   3.47
# 6      중남미   263.42   296.15   6.06
# 0      동유럽   239.47   269.80   7.80
# 2    북미-미국  4035.26  4511.25   8.07
# 4      서유럽  1371.53  1523.55  12.18
# 1   북미-멕시코    38.74    43.34  47.08

# %%
df_results.nsmallest(5, "MAPE")
# Out:
#         국가     MAE    RMSE  MAPE
# 7  중동·아프리카    0.01    0.01  0.00
# 3   북미-캐나다  114.18  161.02  1.09
# 5   아시아-기타  272.70  349.93  3.47
# 6      중남미  263.42  296.15  6.06
# 0      동유럽  239.47  269.80  7.80

# %%
# XGBoost

# %%
import pandas as pd

# %%
df=pd.read_csv('현대_시장구분별_수출실적111.csv')

# %%
df
# Out:
#          국가    연도     1월     2월     3월     4월     5월     6월     7월     8월  \
# 0        기타  2025     46      0      0      0      0      0      0      0
# 1       동유럽  2023   2535   3074   2598   3904   3768   3637   3578   3368
# 2       동유럽  2024   2373   3515   3637   3826   2186   2648   2140   2585
# 3       동유럽  2025   3025      0      0      0      0      0      0      0
# 4    북미-멕시코  2023      8     82     57     45     69     31    202    216
# 5    북미-멕시코  2024     60     51    287    373    194    150    143    146
# 6    북미-멕시코  2025     29      0      0      0      0      0      0      0
# 7     북미-미국  2023  33157  44040  44161  43894  51132  47682  46768  46840
# 8     북미-미국  2024  55421  43704  57669  63939  62068  55809  44859  52389
# 9     북미-미국  2025  41454      0      0      0      0      0      0      0
# 10   북미-캐나다  2023   9824  11958  11464  10792  10478  11495   8383   6155
# 11   북미-캐나다  2024  11189   9437  11914  10738  10512  12175  10867   8529
# 12   북미-캐나다  2025  10472      0      0      0      0      0      0      0
# 13      서유럽  2023  11076  16301  15075  14597  15214  16161  11847   9645
# 14      서유럽  2024   9697   9977  10436  12855   9898   9768   8614   7923
# 15      서유럽  2025  12315      0      0      0      0      0      0      0
# 16   아시아-기타  2023  11288   7295   8997  10570  10678  10496  10563   9940
# 17   아시아-기타  2024   6891   6057   7161   8351   7760   9011   7822   8918
# 18   아시아-기타  2025   6294      0      0      0      0      0      0      0
# 19      중남미  2023   3896   5092   4954   5758   4294   5538   4700   4796
# 20      중남미  2024   4772   4206   4805   4592   3392   4433   3766   3946
# 21      중남미  2025   4157      0      0      0      0      0      0      0
# 22  중동·아프리카  2023  10427  10128  12760  11043   9118   8908   9410   8890
# 23  중동·아프리카  2024   9074   6530   8131   9320   9390   9522  10005   6314
# 24  중동·아프리카  2025   7909      0      0      0      0      0      0      0
#
#        9월    10월    11월    12월
# 0       0      0      0      0
# 1    2604   3321   3165   2721
# 2    4095   4044   3273   2953
# 3       0      0      0      0
# 4      75    130    200    112
# 5     189    153    121     72
# 6       0      0      0      0
# 7   49241  57589  58435  58183
# 8   45941  52255  45782  57802
# 9       0      0      0      0
# 10   6143   9776  10729  11805
# 11  10163  12632   9098  10807
# 12      0      0      0      0
# 13   9535  10378   9522   9637
# 14   7781  10543  11755  12842
# 15      0      0      0      0
# 16   4984  10793   7556   7712
# 17  10004   7142   6838   7324
# 18      0      0      0      0
# 19   4068   5022   3691   4547
# 20   5439   4341   3448   5599
# 21      0      0      0      0
# 22   5963   8258   6651   8346
# 23   7645   9330   8768   8388
# 24      0      0      0      0

# %%
# 2. melt로 월 컬럼 녹이기
df_melted = df.melt(
    id_vars=["국가", "연도"],
    value_vars=["1월", "2월", "3월", "4월", "5월", "6월", "7월", "8월", "9월", "10월", "11월", "12월"],
    var_name="월",
    value_name="y"
)

# 3. 날짜 컬럼 만들기 (ds)
df_melted["월"] = df_melted["월"].str.replace("월", "").astype(int)
df_melted["ds"] = pd.to_datetime(df_melted["연도"].astype(str) + "-" + df_melted["월"].astype(str), format="%Y-%m")



# 4. 수치 변환 및 정리
df_melted["y"] = pd.to_numeric(df_melted["y"], errors="coerce")
df_melted = df_melted.dropna(subset=["y"]).sort_values(["국가", "ds"]).reset_index(drop=True)

cutoff_date = pd.to_datetime("2025-01-31")
df_melted = df_melted[df_melted["ds"] <= cutoff_date].copy()

# %%
df_melted[df_melted['국가']=='동유럽']
# Out:
#      국가    연도   월     y         ds
# 12  동유럽  2023   1  2535 2023-01-01
# 13  동유럽  2023   2  3074 2023-02-01
# 14  동유럽  2023   3  2598 2023-03-01
# 15  동유럽  2023   4  3904 2023-04-01
# 16  동유럽  2023   5  3768 2023-05-01
# 17  동유럽  2023   6  3637 2023-06-01
# 18  동유럽  2023   7  3578 2023-07-01
# 19  동유럽  2023   8  3368 2023-08-01
# 20  동유럽  2023   9  2604 2023-09-01
# 21  동유럽  2023  10  3321 2023-10-01
# 22  동유럽  2023  11  3165 2023-11-01
# 23  동유럽  2023  12  2721 2023-12-01
# 24  동유럽  2024   1  2373 2024-01-01
# 25  동유럽  2024   2  3515 2024-02-01
# 26  동유럽  2024   3  3637 2024-03-01
# 27  동유럽  2024   4  3826 2024-04-01
# 28  동유럽  2024   5  2186 2024-05-01
# 29  동유럽  2024   6  2648 2024-06-01
# 30  동유럽  2024   7  2140 2024-07-01
# 31  동유럽  2024   8  2585 2024-08-01
# 32  동유럽  2024   9  4095 2024-09-01
# 33  동유럽  2024  10  4044 2024-10-01
# 34  동유럽  2024  11  3273 2024-11-01
# 35  동유럽  2024  12  2953 2024-12-01
# 36  동유럽  2025   1  3025 2025-01-01

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 결과 저장 리스트
results = []

# 국가별 루프
for country in df_melted["국가"].unique():
    df_country = df_melted[df_melted["국가"] == country][["ds", "y"]].copy()
    df_country = df_country.sort_values("ds").reset_index(drop=True)

    if len(df_country) < 15:  # 최소 데이터 수 제한
        print(f"[{country}] 데이터 부족으로 스킵")
        continue

    # 날짜 특성 생성
    df_country["year"] = df_country["ds"].dt.year
    df_country["month"] = df_country["ds"].dt.month
    df_country["is_month_start"] = df_country["ds"].dt.is_month_start.astype(int)
    df_country["is_month_end"] = df_country["ds"].dt.is_month_end.astype(int)

    df_country["month_sin"] = np.sin(2 * np.pi * df_country["month"] / 12)
    df_country["month_cos"] = np.cos(2 * np.pi * df_country["month"] / 12)

    # 시차(lag) 변수 생성
    for lag in [1, 2, 3]:
        df_country[f"lag_{lag}"] = df_country["y"].shift(lag)
        # lag1 - 바로 전달의 판매량 / lag2 - 2달 전 판매량 / lag3 - 3달 전 판매량

    df_country = df_country.dropna().reset_index(drop=True)

    # train/test 분리
    train = df_country.iloc[:-12]
    test = df_country.iloc[-12:]

    # ✅ 새 feature 컬럼
    feature_cols = [
    "year", "is_month_start", "is_month_end",
    "month_sin", "month_cos",
    "lag_1", "lag_2", "lag_3"
    ]

    X_train = train[feature_cols]
    y_train = train["y"]
    X_test = test[feature_cols]
    y_test = test["y"]

    # 모델 학습
    model = XGBRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # 예측
    y_pred = model.predict(X_test)

    # 평가
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mape = (np.abs((y_test - y_pred) / y_test)).mean() * 100

    print(f"[{country}] MAE: {mae:.2f}, RMSE: {rmse:.2f}, MAPE: {mape:.2f}%")

    # 결과 저장
    results.append({
        "국가": country,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "MAPE": round(mape, 2)
    })

    # 시각화
    plt.figure(figsize=(10, 5))
    plt.plot(test["ds"], y_test.values, label="실제값", marker='o')
    plt.plot(test["ds"], y_pred, label="예측값", linestyle="--")
    plt.title(f"[{country}] XGBoost 기반 수출 실적 예측")
    plt.xlabel("날짜")
    plt.ylabel("수출량")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xticks(rotation=45)
    # plt.savefig(f"{country}_XGB_수출실적.png")
    plt.show()
# Out:
# [기타] 데이터 부족으로 스킵
# [동유럽] MAE: 864.74, RMSE: 944.21, MAPE: 29.87%
# [북미-멕시코] MAE: 88.20, RMSE: 130.24, MAPE: 49.69%
# [북미-미국] MAE: 8706.46, RMSE: 10230.36, MAPE: 16.70%
# [북미-캐나다] MAE: 1477.10, RMSE: 1842.80, MAPE: 14.21%
# [서유럽] MAE: 1691.80, RMSE: 2009.58, MAPE: 16.18%
# [아시아-기타] MAE: 2790.33, RMSE: 2959.14, MAPE: 37.37%
# [중남미] MAE: 716.53, RMSE: 898.80, MAPE: 17.98%
# [중동·아프리카] MAE: 1420.07, RMSE: 1695.25, MAPE: 18.08%
