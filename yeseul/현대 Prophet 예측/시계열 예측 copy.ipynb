# %%
import pandas as pd

# %%
df=pd.read_csv('../현대_시장구분별_내수차량_모델별월간판매량.csv')

# %%
df_kia=pd.read_csv('../기아_시장구분별_내수차량_모델별월간판매량.csv')

# %%
df_kia
# Out:
#             국가        차량 모델    연도    월   판매량
# 0      중동·아프리카        Bongo  2023   1월     2
# 1      중동·아프리카        Bongo  2024   1월     2
# 2      중동·아프리카        Bongo  2025   1월     2
# 3      중동·아프리카  Bongo (CKD)  2023   1월    24
# 4      중동·아프리카  Bongo (CKD)  2024   1월    24
# ...        ...          ...   ...  ...   ...
# 16483    북미-미국       Stonic  2025  12월   134
# 16484    북미-미국       Stonic  2023  12월   134
# 16485    북미-미국    Telluride  2023  12월  6916
# 16486    북미-미국    Telluride  2024  12월  6916
# 16487    북미-미국    Telluride  2025  12월  6916
#
# [16488 rows x 5 columns]

# %%
df
# Out:
#          국가       차량 모델    연도    월   판매량
# 0     북미-미국      Accent  2023  10월     1
# 1     북미-미국      Accent  2023  11월     1
# 2     북미-미국      Accent  2023  12월     1
# 3     북미-미국      Accent  2023   1월    16
# 4     북미-미국      Accent  2023   2월    12
# ...     ...         ...   ...  ...   ...
# 4327    중남미  HB20 (BR2)  2025   5월  4221
# 4328    중남미  HB20 (BR2)  2025   6월  4221
# 4329    중남미  HB20 (BR2)  2025   7월  4221
# 4330    중남미  HB20 (BR2)  2025   8월  4221
# 4331    중남미  HB20 (BR2)  2025   9월  4221
#
# [4332 rows x 5 columns]

# %%
# 월에서 '월' 글자 제거 → 정수형으로 변환
df["월"] = df["월"].str.replace("월", "").astype(int)

# %%
df
# Out:
#          국가       차량 모델    연도   월   판매량
# 0     북미-미국      Accent  2023  10     1
# 1     북미-미국      Accent  2023  11     1
# 2     북미-미국      Accent  2023  12     1
# 3     북미-미국      Accent  2023   1    16
# 4     북미-미국      Accent  2023   2    12
# ...     ...         ...   ...  ..   ...
# 4327    중남미  HB20 (BR2)  2025   5  4221
# 4328    중남미  HB20 (BR2)  2025   6  4221
# 4329    중남미  HB20 (BR2)  2025   7  4221
# 4330    중남미  HB20 (BR2)  2025   8  4221
# 4331    중남미  HB20 (BR2)  2025   9  4221
#
# [4332 rows x 5 columns]

# %%
df["날짜"] = pd.to_datetime(df["연도"].astype(str) + "-" + df["월"].astype(str), format="%Y-%m")

# %%
df
# Out:
#          국가       차량 모델    연도   월   판매량         날짜
# 0     북미-미국      Accent  2023  10     1 2023-10-01
# 1     북미-미국      Accent  2023  11     1 2023-11-01
# 2     북미-미국      Accent  2023  12     1 2023-12-01
# 3     북미-미국      Accent  2023   1    16 2023-01-01
# 4     북미-미국      Accent  2023   2    12 2023-02-01
# ...     ...         ...   ...  ..   ...        ...
# 4327    중남미  HB20 (BR2)  2025   5  4221 2025-05-01
# 4328    중남미  HB20 (BR2)  2025   6  4221 2025-06-01
# 4329    중남미  HB20 (BR2)  2025   7  4221 2025-07-01
# 4330    중남미  HB20 (BR2)  2025   8  4221 2025-08-01
# 4331    중남미  HB20 (BR2)  2025   9  4221 2025-09-01
#
# [4332 rows x 6 columns]

# %%
df = df[df["날짜"] < "2025-02-01"]

# %%
df['날짜'].unique()
# Out:
# <DatetimeArray>
# ['2023-10-01 00:00:00', '2023-11-01 00:00:00', '2023-12-01 00:00:00',
#  '2023-01-01 00:00:00', '2023-02-01 00:00:00', '2023-03-01 00:00:00',
#  '2023-04-01 00:00:00', '2023-05-01 00:00:00', '2023-06-01 00:00:00',
#  '2023-07-01 00:00:00', '2023-08-01 00:00:00', '2023-09-01 00:00:00',
#  '2024-10-01 00:00:00', '2024-11-01 00:00:00', '2024-12-01 00:00:00',
#  '2024-01-01 00:00:00', '2024-02-01 00:00:00', '2024-03-01 00:00:00',
#  '2024-04-01 00:00:00', '2024-05-01 00:00:00', '2024-06-01 00:00:00',
#  '2024-07-01 00:00:00', '2024-08-01 00:00:00', '2024-09-01 00:00:00',
#  '2025-01-01 00:00:00']
# Length: 25, dtype: datetime64[ns]

# %%
df['차량 모델'].unique()
# Out:
# array(['Accent', 'Elantra', 'Elantra (CN7a)', 'G70', 'G80 (RG3 EV)',
#        'G80 (RG3)', 'G90', 'GV60', 'GV70', 'GV70 (JKa)', 'GV70 EV',
#        'GV70 EV (Jka EV)', 'GV80', 'IONIQ 5', 'IONIQ 5 Robo Taxi',
#        'IONIQ 6', 'Ioniq5 (NEa)', 'Kona', 'Nexo', 'Palisade',
#        'Santa Cruz(Tucson O/B)', 'Santa Fe', 'Santa-Fe (MX5a HEV)',
#        'Santa-Fe (MX5a)', 'Santa-Fe (TMa)', 'Santa-Fe HEV (TMa HEV)',
#        'Sonata', 'Tucson', 'Tucson (NX4a)', 'Tucson OB (NX4a OB)',
#        'Veloster', 'Venue', 'Bayon (BC3 CUV)', 'Casper (AX EV)',
#        'IONIQ (EV)', 'IONIQ (HEV)', 'IONIQ (PHEV)', 'IONIQ 5 (NE N)',
#        'IONIQ 5 (NE)', 'Ioniq6 EV (CE_EV)', 'Kona (EV)', 'Kona (HEV)',
#        'Kona (OS EV)', 'Kona (OS HEV)', 'Kona (OS)', 'Kona (Ose- EV)',
#        'Kona (SX2 HEV)', 'Kona (SX2)', 'Kona (SXe_EV)', 'Kona N',
#        'Kona N (OS N)', 'Light CV', 'NEXO (FE)', 'Santa Fe HEV (MX5 HEV)',
#        'Santa Fe HEV (TM HEV)', 'Santa Fe PHEV (MX5 PHEV)',
#        'Santa Fe PHEV (TM PHEV)', 'Santa-Fe (TM)', 'Tucson (NX4e HEV)',
#        'Tucson (NX4e PHEV)', 'Tucson (NX4e)', 'i10 (AC3)', 'i20 (BC3)',
#        'i20 N (BC3 N)', 'i30 (PD N)', 'i30 (PD)', 'Accent (BN7v)',
#        'Accent (HCv)', 'County (CSv)', 'Creta (SU2id)', 'Creta (SU2v)',
#        'Elantra (CN7v)', 'IONIQ5 (NE)', 'IONIQ5 (NEid N)', 'IONIQ5 (NEv)',
#        'IONIQ6 (CE)', 'Kona (OSv)', 'Kona EV (SX2id EV) ', 'Kusto (KUv)',
#        'Mighty (LTv)', 'Mighty (QTc)', 'Mighty (QTv)', 'Mighty (VTv)',
#        'Palisade (LX2v)', 'Porter (HRv)', 'Santa Fe (MX5v)',
#        'Santa Fe (TMv)', 'Santa Fe HEV (TMv HEV)', 'Santa-Fe (MX5id HEV)',
#        'Santa-Fe (MX5id)', 'Santa-Fe (TMid)', 'Solati (Euv)',
#        'Stargazer (KS)', 'Truck', 'Tucson (NX4v)', 'Venue (QXv)',
#        'i10(AI3v 4DR)', 'i10(AI3v 5DR)', ' Aura (AI3 4DR)',
#        ' Creta (SU2i EV)', ' Creta (SU2i LWB)', ' Creta (SU2i)',
#        ' Grand i10 (AI3 5DR)', ' IONIQ5 (NEi)', ' Kona EV (OSi EV)',
#        ' NIOS (AI3 5DR)', ' Tucson (NX4i)', ' Venue (QXi)',
#        ' Verna (BN7i)', ' Verna (Hci)', ' Xcent (AI3 4DR)',
#        ' i20 (BI3 5DR)', 'Exter (AI3 SUV)', 'IONIQ5 (NEi)',
#        ' Celesta (ID)', ' Custo (KU)', ' Elantra (CN7c)',
#        ' La festa (SQ)', ' Mistra (DU2)', ' Mufasa (NU2)',
#        ' Santa Fe (MX5c)', ' Santa Fe (TMc)', ' Sonata (DN8c)',
#        ' Tucson (NX4c)', ' Tucson HEV (NX4c HEV)', ' Verna (YC)',
#        ' ix35 (NU)', ' ix35 (NU2)', 'HTBC', 'Creta (GSb)', 'Creta (SU2b)',
#        'HB20 (BR2)'], dtype=object)

# %%
df['국가'].unique()
# Out:
# array(['북미-미국', '서유럽', '아시아-기타', '아시아-인도', '아시아-중국', '중남미'], dtype=object)

# %%
df
# Out:
#          국가       차량 모델    연도   월    판매량         날짜
# 0     북미-미국      Accent  2023  10      1 2023-10-01
# 1     북미-미국      Accent  2023  11      1 2023-11-01
# 2     북미-미국      Accent  2023  12      1 2023-12-01
# 3     북미-미국      Accent  2023   1     16 2023-01-01
# 4     북미-미국      Accent  2023   2     12 2023-02-01
# ...     ...         ...   ...  ..    ...        ...
# 4316    중남미  HB20 (BR2)  2024   6  11871 2024-06-01
# 4317    중남미  HB20 (BR2)  2024   7  10270 2024-07-01
# 4318    중남미  HB20 (BR2)  2024   8  11975 2024-08-01
# 4319    중남미  HB20 (BR2)  2024   9  12370 2024-09-01
# 4323    중남미  HB20 (BR2)  2025   1   5104 2025-01-01
#
# [2946 rows x 6 columns]

# %%
df_filtered = df[
    (df["국가"] == "북미-미국") &
    (df["차량 모델"] == "Santa-Fe (MX5a)")
]

# %%
df_filtered
# Out:
#         국가            차량 모델    연도   월    판매량         날짜
# 792  북미-미국  Santa-Fe (MX5a)  2024  10  10053 2024-10-01
# 793  북미-미국  Santa-Fe (MX5a)  2024  11   8141 2024-11-01
# 794  북미-미국  Santa-Fe (MX5a)  2024  12   7784 2024-12-01
# 795  북미-미국  Santa-Fe (MX5a)  2024   1   1935 2024-01-01
# 796  북미-미국  Santa-Fe (MX5a)  2024   2   8882 2024-02-01
# 797  북미-미국  Santa-Fe (MX5a)  2024   3  11326 2024-03-01
# 798  북미-미국  Santa-Fe (MX5a)  2024   4  10577 2024-04-01
# 799  북미-미국  Santa-Fe (MX5a)  2024   5  10474 2024-05-01
# 800  북미-미국  Santa-Fe (MX5a)  2024   6   8263 2024-06-01
# 801  북미-미국  Santa-Fe (MX5a)  2024   7   6780 2024-07-01
# 802  북미-미국  Santa-Fe (MX5a)  2024   8   9518 2024-08-01
# 803  북미-미국  Santa-Fe (MX5a)  2024   9   7769 2024-09-01
# 807  북미-미국  Santa-Fe (MX5a)  2025   1   6052 2025-01-01

# %%
from prophet import Prophet

df_filtered.loc[:, "y"] = df_filtered["판매량"]
df_filtered.loc[:, "ds"] =df_filtered["날짜"]
df_model = df_filtered.dropna(subset=["y"])
if len(df_model) < 2:
    print("예측할 데이터가 부족합니다.")
else:
    model = Prophet()
    model.fit(df_model[["ds", "y"]])
    
    future = model.make_future_dataframe(periods=12, freq="ME")
    forecast = model.predict(future)
    
    print(forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(12))
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/1745610142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:, "y"] = df_filtered["판매량"]
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/1745610142.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:, "ds"] =df_filtered["날짜"]
# 14:21:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:21:09 - cmdstanpy - INFO - Chain [1] done processing
#            ds         yhat   yhat_lower    yhat_upper
# 13 2025-01-31  8296.782499  5335.234859  11334.483280
# 14 2025-02-28  8299.995456  5440.026639  11284.658992
# 15 2025-03-31  8303.552659  5235.309276  11391.901399
# 16 2025-04-30  8306.995113  5319.589365  11370.455758
# 17 2025-05-31  8310.552316  5135.050280  11421.731214
# 18 2025-06-30  8313.994770  5328.304035  11321.600068
# 19 2025-07-31  8317.551973  5493.461099  11495.940419
# 20 2025-08-31  8321.109175  5183.914060  11282.127819
# 21 2025-09-30  8324.551629  5028.332125  11320.382558
# 22 2025-10-31  8328.108832  5460.387869  11425.875635
# 23 2025-11-30  8331.551286  5291.638613  11261.876722
# 24 2025-12-31  8335.108489  5378.674077  11277.231475

# %%
df_eval = pd.merge(df_model[["ds", "y"]], forecast[["ds", "yhat"]], on="ds")

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pandas as pd

# 예측 결과와 실제 데이터 병합
df_eval = pd.merge(df_model[["ds", "y"]], forecast[["ds", "yhat"]], on="ds")

# 성능 지표 계산
mae = mean_absolute_error(df_eval["y"], df_eval["yhat"])
mse = mean_squared_error(df_eval["y"], df_eval["yhat"])
rmse = np.sqrt(mse)
mape = (np.abs((df_eval["y"] - df_eval["yhat"]) / df_eval["y"])).mean() * 100

# 결과 출력
print(f"MAE  (평균 절대 오차): {mae:.2f}")
print(f"RMSE (평균 제곱근 오차): {rmse:.2f}")
print(f"MAPE (평균 절대 비율 오차): {mape:.2f}%")
# Out:
# MAE  (평균 절대 오차): 1726.80
# RMSE (평균 제곱근 오차): 2359.99
# MAPE (평균 절대 비율 오차): 39.09%

# %%
import matplotlib.pyplot as plt

# 날짜 정렬
df_eval["ds"] = pd.to_datetime(df_eval["ds"])
df_eval = df_eval.sort_values("ds")

plt.figure(figsize=(12, 6))
plt.plot(df_eval["ds"], df_eval["y"], label="실제값", marker='o')
plt.plot(df_eval["ds"], df_eval["yhat"], label="예측값", linestyle='--', marker='x')

plt.title("Prophet 예측 vs 실제 판매량")
plt.xlabel("날짜")
plt.ylabel("판매량")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)  # 날짜가 겹치지 않게 회전
plt.show()
# Out:
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /var/folders/wz/cf10k4857715p70flsxw2g9m0000gn/T/ipykernel_55399/4048657518.py:16: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54032 (\N{HANGUL SYLLABLE PAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

# %%
df=pd.read_csv('현대_시장구분별_수출실적.csv')

# %%
df['국가'].unique()
# Out:
# array(['기타', '동유럽', '북미-멕시코', '북미-미국', '북미-캐나다', '서유럽', '아시아-기타', '중남미',
#        '중동·아프리카'], dtype=object)

# %%
df.head()
# Out:
#     국가    연도  월     y          ds
# 0   기타  2025  1    46  2025-01-01
# 1  동유럽  2023  1  2535  2023-01-01
# 2  동유럽  2023  2  3074  2023-02-01
# 3  동유럽  2023  3  2598  2023-03-01
# 4  동유럽  2023  4  3904  2023-04-01

# %%
df = df.groupby(["국가", "연도"], as_index=False).sum(numeric_only=True)

# %%
df
# Out:
#          국가    연도   월       y
# 0        기타  2025   1      46
# 1       동유럽  2023  78   38273
# 2       동유럽  2024  78   37275
# 3       동유럽  2025   1    3025
# 4    북미-멕시코  2023  78    1227
# 5    북미-멕시코  2024  78    1939
# 6    북미-멕시코  2025   1      29
# 7     북미-미국  2023  78  581122
# 8     북미-미국  2024  78  637638
# 9     북미-미국  2025   1   41454
# 10   북미-캐나다  2023  78  119002
# 11   북미-캐나다  2024  78  128061
# 12   북미-캐나다  2025   1   10472
# 13      서유럽  2023  78  148988
# 14      서유럽  2024  78  122089
# 15      서유럽  2025   1   12315
# 16   아시아-기타  2023  78  110872
# 17   아시아-기타  2024  78   93279
# 18   아시아-기타  2025   1    6294
# 19      중남미  2023  78   56356
# 20      중남미  2024  78   52739
# 21      중남미  2025   1    4157
# 22  중동·아프리카  2023  78  109902
# 23  중동·아프리카  2024  78  102417
# 24  중동·아프리카  2025   1    7909

# %%
df['국가'].unique()
# Out:
# array(['기타', '동유럽', '북미-멕시코', '북미-미국', '북미-캐나다', '서유럽', '아시아-기타', '중남미',
#        '중동·아프리카'], dtype=object)

# %%
# 2. melt로 월 컬럼 녹이기
df_melted = df.melt(
    id_vars=["국가", "연도"],
    value_vars=["1월", "2월", "3월", "4월", "5월", "6월", "7월", "8월", "9월", "10월", "11월", "12월"],
    var_name="월",
    value_name="y"
)

# 3. 날짜 컬럼 만들기 (ds)
df_melted["월"] = df_melted["월"].str.replace("월", "").astype(int)
df_melted["ds"] = pd.to_datetime(df_melted["연도"].astype(str) + "-" + df_melted["월"].astype(str), format="%Y-%m")



# 4. 수치 변환 및 정리
df_melted["y"] = pd.to_numeric(df_melted["y"], errors="coerce")
df_melted = df_melted.dropna(subset=["y"]).sort_values(["국가", "ds"]).reset_index(drop=True)

cutoff_date = pd.to_datetime("2025-01-31")
df_melted = df_melted[df_melted["ds"] <= cutoff_date].copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 2
#       1 # 2. melt로 월 컬럼 녹이기
# ----> 2 df_melted = df.melt(
#       3     id_vars=["국가", "연도"],
#       4     value_vars=["1월", "2월", "3월", "4월", "5월", "6월", "7월", "8월", "9월", "10월", "11월", "12월"],
#       5     var_name="월",
#       6     value_name="y"
#       7 )
#       9 # 3. 날짜 컬럼 만들기 (ds)
#      10 df_melted["월"] = df_melted["월"].str.replace("월", "").astype(int)
#
# File /opt/anaconda3/envs/hi/lib/python3.10/site-packages/pandas/core/frame.py:9942, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9932 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9933 def melt(
#    9934     self,
#    (...)
#    9940     ignore_index: bool = True,
#    9941 ) -> DataFrame:
# -> 9942     return melt(
#    9943         self,
#    9944         id_vars=id_vars,
#    9945         value_vars=value_vars,
#    9946         var_name=var_name,
#    9947         value_name=value_name,
#    9948         col_level=col_level,
#    9949         ignore_index=ignore_index,
#    9950     ).__finalize__(self, method="melt")
#
# File /opt/anaconda3/envs/hi/lib/python3.10/site-packages/pandas/core/reshape/melt.py:54, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      43 @Appender(_shared_docs["melt"] % {"caller": "pd.melt(df, ", "other": "DataFrame.melt"})
#      44 def melt(
#      45     frame: DataFrame,
#    (...)
#      51     ignore_index: bool = True,
#      52 ) -> DataFrame:
#      53     if value_name in frame.columns:
# ---> 54         raise ValueError(
#      55             f"value_name ({value_name}) cannot match an element in "
#      56             "the DataFrame columns."
#      57         )
#      58     id_vars = ensure_list_vars(id_vars, "id_vars", frame.columns)
#      59     value_vars_was_not_none = value_vars is not None
#
# ValueError: value_name (y) cannot match an element in the DataFrame columns.

# %%
df_melted
# Out:
#           국가    연도   월     y         ds
# 0         기타  2025   1    46 2025-01-01
# 12       동유럽  2023   1  2535 2023-01-01
# 13       동유럽  2023   2  3074 2023-02-01
# 14       동유럽  2023   3  2598 2023-03-01
# 15       동유럽  2023   4  3904 2023-04-01
# ..       ...   ...  ..   ...        ...
# 284  중동·아프리카  2024   9  7645 2024-09-01
# 285  중동·아프리카  2024  10  9330 2024-10-01
# 286  중동·아프리카  2024  11  8768 2024-11-01
# 287  중동·아프리카  2024  12  8388 2024-12-01
# 288  중동·아프리카  2025   1  7909 2025-01-01
#
# [201 rows x 5 columns]

# %%
df_melted.to_csv('현대_시장구분별_수출실적.csv', index=False)

# %%
import os
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
import pickle

plt.rc('font', family='NanumGothic')

# 저장 폴더 없으면 생성
os.makedirs("models", exist_ok=True)

results = []

for country in df_melted["국가"].unique():
    df_country = df_melted[df_melted["국가"] == country][["ds", "y"]].copy()

    if len(df_country) < 12:
        print(f"[{country}] 데이터 부족으로 스킵")
        continue

    model = Prophet(daily_seasonality=False)
    model.fit(df_country)

    # 모델 저장
    with open(f"models/{country}_prophet.pkl", "wb") as f:
        pickle.dump(model, f)

    # 예측
    future = model.make_future_dataframe(periods=18, freq="ME")
    forecast = model.predict(future)

    # 병합 후 평가
    df_eval = pd.merge(df_country, forecast[["ds", "yhat"]], on="ds", how="inner")
    df_eval = df_eval[df_eval["y"] != 0]

    if len(df_eval) == 0:
        print(f"[{country}] 평가 불가 (y가 모두 0)")
        continue

    mae = mean_absolute_error(df_eval["y"], df_eval["yhat"])
    rmse = np.sqrt(mean_squared_error(df_eval["y"], df_eval["yhat"]))
    mape = (np.abs((df_eval["y"] - df_eval["yhat"]) / df_eval["y"])).mean() * 100

    results.append({
        "국가": country,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "MAPE": round(mape, 2)
    })

    # 시각화
    plt.figure(figsize=(10, 5))
    plt.plot(df_country["ds"], df_country["y"], label="실제값", marker='o')
    plt.plot(forecast["ds"], forecast["yhat"], label="예측값", linestyle="--")
    plt.fill_between(forecast["ds"], forecast["yhat_lower"], forecast["yhat_upper"], alpha=0.2, label="신뢰구간")
    plt.title(f"[{country}] 수출 실적 예측")
    plt.xlabel("날짜")
    plt.ylabel("수출량")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.savefig(f"{country}_수출실적.png")
    plt.show()
# Out:
# 15:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:33 - cmdstanpy - INFO - Chain [1] done processing
# [기타] 데이터 부족으로 스킵
# 15:04:33 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:33 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] done processing
# 15:04:35 - cmdstanpy - INFO - Chain [1] start processing
# 15:04:41 - cmdstanpy - INFO - Chain [1] done processing

# %%
df_seu = df_melted[df_melted["국가"] == "서유럽"].copy()
df_seu
# Out:
#       국가    연도   월      y         ds
# 156  서유럽  2023   1  11076 2023-01-01
# 157  서유럽  2023   2  16301 2023-02-01
# 158  서유럽  2023   3  15075 2023-03-01
# 159  서유럽  2023   4  14597 2023-04-01
# 160  서유럽  2023   5  15214 2023-05-01
# 161  서유럽  2023   6  16161 2023-06-01
# 162  서유럽  2023   7  11847 2023-07-01
# 163  서유럽  2023   8   9645 2023-08-01
# 164  서유럽  2023   9   9535 2023-09-01
# 165  서유럽  2023  10  10378 2023-10-01
# 166  서유럽  2023  11   9522 2023-11-01
# 167  서유럽  2023  12   9637 2023-12-01
# 168  서유럽  2024   1   9697 2024-01-01
# 169  서유럽  2024   2   9977 2024-02-01
# 170  서유럽  2024   3  10436 2024-03-01
# 171  서유럽  2024   4  12855 2024-04-01
# 172  서유럽  2024   5   9898 2024-05-01
# 173  서유럽  2024   6   9768 2024-06-01
# 174  서유럽  2024   7   8614 2024-07-01
# 175  서유럽  2024   8   7923 2024-08-01
# 176  서유럽  2024   9   7781 2024-09-01
# 177  서유럽  2024  10  10543 2024-10-01
# 178  서유럽  2024  11  11755 2024-11-01
# 179  서유럽  2024  12  12842 2024-12-01
# 180  서유럽  2025   1  12315 2025-01-01

# %%
df_results = pd.DataFrame(results)
display(df_results.sort_values("MAPE"))  # MAPE 기준 정렬
# Out:
#         국가      MAE     RMSE   MAPE
# 7  중동·아프리카     0.03     0.04   0.00
# 3   북미-캐나다   112.76   168.16   1.06
# 5   아시아-기타   461.51   592.09   5.78
# 6      중남미   261.78   293.73   6.03
# 0      동유럽   239.73   270.37   7.82
# 2    북미-미국  4020.66  4538.25   8.06
# 4      서유럽  1329.46  1497.36  11.87
# 1   북미-멕시코    34.29    38.77  41.60

# %%
df_results.nsmallest(5, "MAPE")
# Out:
#         국가     MAE    RMSE  MAPE
# 7  중동·아프리카    0.03    0.04  0.00
# 3   북미-캐나다  112.76  168.16  1.06
# 5   아시아-기타  461.51  592.09  5.78
# 6      중남미  261.78  293.73  6.03
# 0      동유럽  239.73  270.37  7.82

# %%
# XGBoost

# %%
import pandas as pd

# %%
df=pd.read_csv('현대_시장구분별_수출실적111.csv')

# %%
df
# Out:
#          국가    연도     1월     2월     3월     4월     5월     6월     7월     8월  \
# 0        기타  2025     46      0      0      0      0      0      0      0
# 1       동유럽  2023   2535   3074   2598   3904   3768   3637   3578   3368
# 2       동유럽  2024   2373   3515   3637   3826   2186   2648   2140   2585
# 3       동유럽  2025   3025      0      0      0      0      0      0      0
# 4    북미-멕시코  2023      8     82     57     45     69     31    202    216
# 5    북미-멕시코  2024     60     51    287    373    194    150    143    146
# 6    북미-멕시코  2025     29      0      0      0      0      0      0      0
# 7     북미-미국  2023  33157  44040  44161  43894  51132  47682  46768  46840
# 8     북미-미국  2024  55421  43704  57669  63939  62068  55809  44859  52389
# 9     북미-미국  2025  41454      0      0      0      0      0      0      0
# 10   북미-캐나다  2023   9824  11958  11464  10792  10478  11495   8383   6155
# 11   북미-캐나다  2024  11189   9437  11914  10738  10512  12175  10867   8529
# 12   북미-캐나다  2025  10472      0      0      0      0      0      0      0
# 13      서유럽  2023  11076  16301  15075  14597  15214  16161  11847   9645
# 14      서유럽  2024   9697   9977  10436  12855   9898   9768   8614   7923
# 15      서유럽  2025  12315      0      0      0      0      0      0      0
# 16   아시아-기타  2023  11288   7295   8997  10570  10678  10496  10563   9940
# 17   아시아-기타  2024   6891   6057   7161   8351   7760   9011   7822   8918
# 18   아시아-기타  2025   6294      0      0      0      0      0      0      0
# 19      중남미  2023   3896   5092   4954   5758   4294   5538   4700   4796
# 20      중남미  2024   4772   4206   4805   4592   3392   4433   3766   3946
# 21      중남미  2025   4157      0      0      0      0      0      0      0
# 22  중동·아프리카  2023  10427  10128  12760  11043   9118   8908   9410   8890
# 23  중동·아프리카  2024   9074   6530   8131   9320   9390   9522  10005   6314
# 24  중동·아프리카  2025   7909      0      0      0      0      0      0      0
#
#        9월    10월    11월    12월
# 0       0      0      0      0
# 1    2604   3321   3165   2721
# 2    4095   4044   3273   2953
# 3       0      0      0      0
# 4      75    130    200    112
# 5     189    153    121     72
# 6       0      0      0      0
# 7   49241  57589  58435  58183
# 8   45941  52255  45782  57802
# 9       0      0      0      0
# 10   6143   9776  10729  11805
# 11  10163  12632   9098  10807
# 12      0      0      0      0
# 13   9535  10378   9522   9637
# 14   7781  10543  11755  12842
# 15      0      0      0      0
# 16   4984  10793   7556   7712
# 17  10004   7142   6838   7324
# 18      0      0      0      0
# 19   4068   5022   3691   4547
# 20   5439   4341   3448   5599
# 21      0      0      0      0
# 22   5963   8258   6651   8346
# 23   7645   9330   8768   8388
# 24      0      0      0      0

# %%
# 2. melt로 월 컬럼 녹이기
df_melted = df.melt(
    id_vars=["국가", "연도"],
    value_vars=["1월", "2월", "3월", "4월", "5월", "6월", "7월", "8월", "9월", "10월", "11월", "12월"],
    var_name="월",
    value_name="y"
)

# 3. 날짜 컬럼 만들기 (ds)
df_melted["월"] = df_melted["월"].str.replace("월", "").astype(int)
df_melted["ds"] = pd.to_datetime(df_melted["연도"].astype(str) + "-" + df_melted["월"].astype(str), format="%Y-%m")



# 4. 수치 변환 및 정리
df_melted["y"] = pd.to_numeric(df_melted["y"], errors="coerce")
df_melted = df_melted.dropna(subset=["y"]).sort_values(["국가", "ds"]).reset_index(drop=True)

cutoff_date = pd.to_datetime("2025-01-31")
df_melted = df_melted[df_melted["ds"] <= cutoff_date].copy()

# %%
df_melted[df_melted['국가']=='동유럽']
# Out:
#      국가    연도   월     y         ds
# 12  동유럽  2023   1  2535 2023-01-01
# 13  동유럽  2023   2  3074 2023-02-01
# 14  동유럽  2023   3  2598 2023-03-01
# 15  동유럽  2023   4  3904 2023-04-01
# 16  동유럽  2023   5  3768 2023-05-01
# 17  동유럽  2023   6  3637 2023-06-01
# 18  동유럽  2023   7  3578 2023-07-01
# 19  동유럽  2023   8  3368 2023-08-01
# 20  동유럽  2023   9  2604 2023-09-01
# 21  동유럽  2023  10  3321 2023-10-01
# 22  동유럽  2023  11  3165 2023-11-01
# 23  동유럽  2023  12  2721 2023-12-01
# 24  동유럽  2024   1  2373 2024-01-01
# 25  동유럽  2024   2  3515 2024-02-01
# 26  동유럽  2024   3  3637 2024-03-01
# 27  동유럽  2024   4  3826 2024-04-01
# 28  동유럽  2024   5  2186 2024-05-01
# 29  동유럽  2024   6  2648 2024-06-01
# 30  동유럽  2024   7  2140 2024-07-01
# 31  동유럽  2024   8  2585 2024-08-01
# 32  동유럽  2024   9  4095 2024-09-01
# 33  동유럽  2024  10  4044 2024-10-01
# 34  동유럽  2024  11  3273 2024-11-01
# 35  동유럽  2024  12  2953 2024-12-01
# 36  동유럽  2025   1  3025 2025-01-01

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 결과 저장 리스트
results = []

# 국가별 루프
for country in df_melted["국가"].unique():
    df_country = df_melted[df_melted["국가"] == country][["ds", "y"]].copy()
    df_country = df_country.sort_values("ds").reset_index(drop=True)

    if len(df_country) < 15:  # 최소 데이터 수 제한
        print(f"[{country}] 데이터 부족으로 스킵")
        continue

    # 날짜 특성 생성
    df_country["year"] = df_country["ds"].dt.year
    df_country["month"] = df_country["ds"].dt.month
    df_country["is_month_start"] = df_country["ds"].dt.is_month_start.astype(int)
    df_country["is_month_end"] = df_country["ds"].dt.is_month_end.astype(int)

    df_country["month_sin"] = np.sin(2 * np.pi * df_country["month"] / 12)
    df_country["month_cos"] = np.cos(2 * np.pi * df_country["month"] / 12)

    # 시차(lag) 변수 생성
    for lag in [1, 2, 3]:
        df_country[f"lag_{lag}"] = df_country["y"].shift(lag)
        # lag1 - 바로 전달의 판매량 / lag2 - 2달 전 판매량 / lag3 - 3달 전 판매량

    df_country = df_country.dropna().reset_index(drop=True)

    # train/test 분리
    train = df_country.iloc[:-12]
    test = df_country.iloc[-12:]

    # ✅ 새 feature 컬럼
    feature_cols = [
    "year", "is_month_start", "is_month_end",
    "month_sin", "month_cos",
    "lag_1", "lag_2", "lag_3"
    ]

    X_train = train[feature_cols]
    y_train = train["y"]
    X_test = test[feature_cols]
    y_test = test["y"]

    # 모델 학습
    model = XGBRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # 예측
    y_pred = model.predict(X_test)

    # 평가
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mape = (np.abs((y_test - y_pred) / y_test)).mean() * 100

    print(f"[{country}] MAE: {mae:.2f}, RMSE: {rmse:.2f}, MAPE: {mape:.2f}%")

    # 결과 저장
    results.append({
        "국가": country,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "MAPE": round(mape, 2)
    })

    # 시각화
    plt.figure(figsize=(10, 5))
    plt.plot(test["ds"], y_test.values, label="실제값", marker='o')
    plt.plot(test["ds"], y_pred, label="예측값", linestyle="--")
    plt.title(f"[{country}] XGBoost 기반 수출 실적 예측")
    plt.xlabel("날짜")
    plt.ylabel("수출량")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.xticks(rotation=45)
    plt.savefig(f"{country}_XGB_수출실적.png")
    plt.show()
# Out:
# [기타] 데이터 부족으로 스킵
# [동유럽] MAE: 864.74, RMSE: 944.21, MAPE: 29.87%
# [북미-멕시코] MAE: 88.20, RMSE: 130.24, MAPE: 49.69%
# [북미-미국] MAE: 8706.46, RMSE: 10230.36, MAPE: 16.70%
# [북미-캐나다] MAE: 1477.10, RMSE: 1842.80, MAPE: 14.21%
# [서유럽] MAE: 1691.80, RMSE: 2009.58, MAPE: 16.18%
# [아시아-기타] MAE: 2790.33, RMSE: 2959.14, MAPE: 37.37%
# [중남미] MAE: 716.53, RMSE: 898.80, MAPE: 17.98%
# [중동·아프리카] MAE: 1420.07, RMSE: 1695.25, MAPE: 18.08%

# %%
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

plt.rc('font', family='NanumGothic')

# 모델 저장 폴더
os.makedirs("models", exist_ok=True)

results = []

for country in df_melted["국가"].unique():
    df_country = df_melted[df_melted["국가"] == country][["ds", "y"]].copy()

    if len(df_country) < 12:
        print(f"[{country}] 데이터 부족으로 스킵")
        continue

    model = Prophet(daily_seasonality=False)
    model.fit(df_country)

    # 모델 저장
    with open(f"models/{country}_prophet.pkl", "wb") as f:
        pickle.dump(model, f)

    # 예측 결과 저장용 (원하는 경우)
    future = model.make_future_dataframe(periods=12, freq="ME")
    forecast = model.predict(future)

    df_eval = pd.merge(df_country, forecast[["ds", "yhat"]], on="ds", how="inner")
    df_eval = df_eval[df_eval["y"] != 0]

    if len(df_eval) == 0:
        continue

    mae = mean_absolute_error(df_eval["y"], df_eval["yhat"])
    rmse = np.sqrt(mean_squared_error(df_eval["y"], df_eval["yhat"]))
    mape = (np.abs((df_eval["y"] - df_eval["yhat"]) / df_eval["y"])).mean() * 100

    results.append({
        "국가": country,
        "MAE": round(mae, 2),
        "RMSE": round(rmse, 2),
        "MAPE": round(mape, 2)
    })

print("모델 저장 완료")
# Out:
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# [기타] 데이터 부족으로 스킵
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:32:22 - cmdstanpy - INFO - Chain [1] done processing
# 모델 저장 완료
